# %% [markdown]
# Here we'd be importng quite a few things different from the usual import we've been doing

# %%
#first we'd import our usuals :
import pandas as pd
import numpy as np
from pandas import Series , DataFrame
from numpy.random import randn

# %%
#next we import some useful data visual. tool:
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
set1 = randn(100)
set1
# Out:
# array([ 0.27585098, -0.78889782,  1.54617835, -1.18488515,  0.52913252,
#         0.20416541, -0.9910765 , -0.27883617, -0.43350801,  0.18465827,
#        -0.24079394,  0.30660086,  1.58550553, -1.00398014,  0.29077424,
#        -0.70118581,  0.80789237,  0.8196497 , -0.70369823,  1.7834353 ,
#         0.91123581, -1.97405436,  0.15098677,  0.67696132,  0.13202158,
#        -2.18585152,  0.18144743, -0.73504539, -1.26254529, -1.31154745,
#        -0.42128639,  1.09178272, -0.07631374,  1.40733613,  0.40660947,
#         1.58561413,  1.4738451 ,  0.78458298,  0.85232033, -0.61872865,
#         0.99494055,  1.13559311, -0.26795596,  0.0215057 ,  0.66521636,
#        -0.02200275,  0.40419358,  0.3138218 , -0.36056142,  0.7057453 ,
#        -1.5409832 ,  0.53926571, -0.28102902,  0.4134633 ,  1.43768283,
#        -2.11426912, -0.27645646, -0.1195862 , -0.25506972, -0.50955228,
#         0.43814139, -0.00781777,  1.07716807, -0.34663371,  0.0624683 ,
# ...

# %%
plt.hist(set1)
# Out:
# (array([ 5.,  9., 14., 22., 15., 15.,  9.,  9.,  1.,  1.]),
#  array([-2.18585152, -1.68644092, -1.18703031, -0.68761971, -0.18820911,
#          0.3112015 ,  0.8106121 ,  1.31002271,  1.80943331,  2.30884392,
#          2.80825452]),
#  <BarContainer object of 10 artists>)

# %%
set2 = randn(80)

# %%
plt.hist(set2, color = 'indianred')
# Out:
# (array([ 1.,  3.,  5.,  6., 17., 15., 17., 11.,  3.,  2.]),
#  array([-2.95112373, -2.42221918, -1.89331462, -1.36441006, -0.8355055 ,
#         -0.30660094,  0.22230361,  0.75120817,  1.28011273,  1.80901729,
#          2.33792185]),
#  <BarContainer object of 10 artists>)

# %%
# alpha ia used here to catalyze transparency of given histogram plot

# %%
plt.hist(set1, color = 'pink', normed = True, alpha= 0.8, bins = 20 )
plt.hist(set2,color = 'grey',normed = True, alpha = 0.5, bins= 20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plt.hist(set1, color = 'pink', normed = True, alpha= 0.8, bins = 20 )
#       2 plt.hist(set2,color = 'grey',normed = True, alpha = 0.5, bins= 20)
#
# File ~\anaconda3\a4\Lib\site-packages\matplotlib\pyplot.py:3224, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3199 @_copy_docstring_and_deprecators(Axes.hist)
#    3200 def hist(
#    3201     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3222     BarContainer | Polygon | list[BarContainer | Polygon],
#    3223 ]:
# -> 3224     return gca().hist(
#    3225         x,
#    3226         bins=bins,
#    3227         range=range,
#    3228         density=density,
#    3229         weights=weights,
#    3230         cumulative=cumulative,
# ...

# %%
# to run joint plot:

# %%
set3 = randn(1000)
set4 = randn(1000)

# %%
sns.jointplot(x= set3, y= set4, color = 'grey')
# Out:
# C:\Users\HP\anaconda3\a4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\a4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x= set3, y= set4, color = 'indianred', kind = 'hex')
# Out:
# C:\Users\HP\anaconda3\a4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\a4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
