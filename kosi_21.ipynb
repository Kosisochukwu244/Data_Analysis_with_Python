# %%
import numpy as np

import pandas as pd

from pandas import Series, DataFrame

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/'

# %%
url2 = 'https://archive.ics.uci.edu/dataset/109/wine'

# %%
import os

# %%
kd = os.getcwd()

kd
# Out:
# 'C:\\Users\\HP'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP'

# %%
mydframe = pd.read_csv('k_d.csv', sep = ';')


mydframe.head(2000)
# Out:
#                                           fixed acidity  volatile acidity  \
# 0                                                   7.4              0.70
# 1                                                   7.8              0.88
# 2                                                   7.8              0.76
# 3                                                  11.2              0.28
# 4                                                   7.4              0.70
# ...                                                 ...               ...
# 1608                    pH\tFeature\tContinuous\t\t\tno               NaN
# 1609             sulphates\tFeature\tContinuous\t\t\tno               NaN
# 1610               alcohol\tFeature\tContinuous\t\t\tno               NaN
# 1611  quality\tTarget\tInteger\tscore between 0 and ...               NaN
# 1612       color\tOther\tCategorical\tred or white\t\tn               NaN
#
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
mydframe.describe().head()
# Out:
#        volatile acidity  citric acid  residual sugar    chlorides  \
# count       1599.000000  1599.000000     1599.000000  1599.000000
# mean           0.527821     0.270976        2.538806     0.087467
# std            0.179060     0.194801        1.409928     0.047065
# min            0.120000     0.000000        0.900000     0.012000
# 25%            0.390000     0.090000        1.900000     0.070000
#
#        free sulfur dioxide  total sulfur dioxide      density           pH  \
# count          1599.000000           1599.000000  1599.000000  1599.000000
# mean             15.874922             46.467792     0.996747     3.311113
# std              10.460157             32.895324     0.001887     0.154386
# min               1.000000              6.000000     0.990070     2.740000
# 25%               7.000000             22.000000     0.995600     3.210000
#
#          sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000
# ...

# %%
mydframe['alcohol'].mean()
# Out:
# 10.42298311444653

# %%
mydframe['alcohol'].max()
# Out:
# 14.9

# %%
mydframe
# Out:
#                                           fixed acidity  volatile acidity  \
# 0                                                   7.4              0.70
# 1                                                   7.8              0.88
# 2                                                   7.8              0.76
# 3                                                  11.2              0.28
# 4                                                   7.4              0.70
# ...                                                 ...               ...
# 1608                    pH\tFeature\tContinuous\t\t\tno               NaN
# 1609             sulphates\tFeature\tContinuous\t\t\tno               NaN
# 1610               alcohol\tFeature\tContinuous\t\t\tno               NaN
# 1611  quality\tTarget\tInteger\tscore between 0 and ...               NaN
# 1612       color\tOther\tCategorical\tred or white\t\tn               NaN
#
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
mydframe.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1608          False              True         True            True       True
# 1609          False              True         True            True       True
# 1610          False              True         True            True       True
# 1611          False              True         True            True       True
# 1612          False              True         True            True       True
#
# ...

# %%
def max_to_min (arr):
    return arr.max() - arr.min()

# %%
dimin = mydframe.groupby('quality')


dimin.describe()
# Out:
#         volatile acidity                                                   \
#                    count      mean       std   min     25%    50%     75%
# quality
# 3.0                 10.0  0.884500  0.331256  0.44  0.6475  0.845  1.0100
# 4.0                 53.0  0.693962  0.220110  0.23  0.5300  0.670  0.8700
# 5.0                681.0  0.577041  0.164801  0.18  0.4600  0.580  0.6700
# 6.0                638.0  0.497484  0.160962  0.16  0.3800  0.490  0.6000
# 7.0                199.0  0.403920  0.145224  0.12  0.3000  0.370  0.4850
# 8.0                 18.0  0.423333  0.144914  0.26  0.3350  0.370  0.4725
#
#                citric acid            ... sulphates       alcohol             \
#            max       count      mean  ...       75%   max   count       mean
# quality                               ...
# 3.0      1.580        10.0  0.171000  ...     0.615  0.86    10.0   9.955000
# 4.0      1.130        53.0  0.174151  ...     0.600  2.00    53.0  10.265094
# ...

# %%
numerical_cols = mydframe.select_dtypes(include='number').columns

# %%
mydframe.head()
# Out:
#   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.4              0.70         0.00             1.9      0.076
# 1           7.8              0.88         0.00             2.6      0.098
# 2           7.8              0.76         0.04             2.3      0.092
# 3          11.2              0.28         0.56             1.9      0.075
# 4           7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %%
mydframe['citric-acid-chlorides  ratio'] = mydframe['citric acid'] / mydframe['chlorides']

mydframe.head()
# Out:
#   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.4              0.70         0.00             1.9      0.076
# 1           7.8              0.88         0.00             2.6      0.098
# 2           7.8              0.76         0.04             2.3      0.092
# 3          11.2              0.28         0.56             1.9      0.075
# 4           7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  citric-acid-chlorides  ratio
# ...

# %%
# NB YOu can also use the pivot method to perform certain functions the groupby would do

# %%
# %matplotlib inline

# %%
mydframe.plot(kind = 'scatter', x = 'pH', y= 'density')
# Out:
# <Axes: xlabel='pH', ylabel='density'>
