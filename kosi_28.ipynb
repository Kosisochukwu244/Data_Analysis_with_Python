# %%
#first we'd import our usuals :
import pandas as pd
import numpy as np
from pandas import Series , DataFrame
from numpy.random import randn

# %%
#next we import some useful data visual. tool:
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP'

# %%
dset = read_csv()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dset = read_csv()
#
# NameError: name 'read_csv' is not defined

# %%
url = 'http://en.wikipedia.org/wiki/Box_plot#mediaviewer/File:Boxplot_vs_PDF.svg'

# %%
dset1 = randn(500)
dset2 = randn(500)

# %%
sns.boxplot([dset1, dset2], color = 'red')
# Out:
# <Axes: >

# %%
sns.boxplot([dset1, dset2], whis = np.inf)
# Out:
# <Axes: >

# %% [raw]
# boxplots are basically ideal for financial data

# %%
dset1 = stats.norm(0,5).rvs(100)


dset2 = np.concatenate([stats.gamma(5).rvs(50)-1,
                       -1* stats.gamma(5).rvs(50)])

sns.boxplot([dset1, dset2], whis = np.inf)
# Out:
# <Axes: >

# %%
sns.violinplot([dset1, dset2], bw = .1)
# Out:
# <Axes: >

# %%
sns.violinplot(dset1)
# Out:
# <Axes: >

# %%
sns.violinplot(dset1, inner = 'stick', color = 'grey')
# Out:
# <Axes: >

# %%
tips = sns.load_dataset('tips')

tips.head()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\a4\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\a4\Lib\http\client.py:1294, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1293 """Send a complete request to the server."""
# -> 1294 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\a4\Lib\http\client.py:1340, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1339     body = _encode(body, 'body')
# -> 1340 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...
